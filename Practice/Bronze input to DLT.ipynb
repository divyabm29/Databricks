# %%
# Delta Live Table (DLT) Bronze-silver pipeline
# this simulates the raw ingested data
data=[
    (1,"Alice",25),
    (2,"Bob",None),
    (3,"Charlie",30),
    (4,None,40)
]
columns=["id","name","age"]
df=spark.createDataFrame(data,columns)
df.write.format("delta").mode("overwrite").save("/Volumes/workspace/default/datafiles/tmp/dlt_lab/raw_users")
