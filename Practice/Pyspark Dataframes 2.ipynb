# %%
# filter operation
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName('dataframe practice 2').getOrCreate()

# %%
df3=spark.read.option('header','true').csv('/Workspace/Repos/pusthakaloka@gmail.com/Databricks/Practice/testdata2.csv',inferSchema='true')
df3.show()

# %%
# Filter Operations
# salary of people <=20000

df3.filter("Salary<=20000").show()

# %%
df3.filter("Salary<=20000").select(["Name","Experience"]).show()
