-- %%
SELECT lpep_pickup_datetime, revenue FROM delta.`/Volumes/workspace/default/datafiles/gold_daily_revenue`
ORDER BY lpep_pickup_datetime;

OPTIMIZE delta.`/Volumes/workspace/default/datafiles/gold_daily_revenue`ZORDER BY (lpep_pickup_datetime);
